# %% [markdown]
# # wangchao(王超)

# %% [markdown]
# Q1:已经读过了

# %% [markdown]
# Q2:for a)
# 通过stellarium，我选取了视星等最大的20个恒星，它们在HR图上是这样的（因为之前画过pref.Greg的图，就直接用M53的HR图了）：

# %%
run makeplot420.py
# Out:
# WARNING: VerifyWarning: Invalid keyword for column 6: ASCII table null option (TNULLn) is longer than the column's character width and will be truncated (got '-32768'). [astropy.io.fits.column]

# %% [markdown]
# 主序带上的恒星比例大约是50%，远远低于应有的比例，猜想是因为主序带上的星主要分布在较暗较冷的地方，所以最亮的星体里主序带上的星比较少（太阳就比较暗了）

# %% [markdown]
# Q3考虑到样本量的影响，我选取尽量多的11万个源。通过距离矫正为绝对星等，做出HR图
#   由于主序带上的恒星光度和质量的3.5次方成正比，换算为当前质量函数。
#   考虑到恒星质量和在主序带上的寿命时标，以及观测中选择效应带来的影响（比较暗时会看不到恒星），我选择比较亮的一侧进行拟合，其中假设恒星的形成率不变且一致。

# %%
run plot_IMF.py
# Out:
# C:\Users\chaowang\homeworkforweek2\plot_IMF.py:11: RuntimeWarning: divide by zero encountered in log
#   Mag[i]=rawdata[i][1]-10+5*(np.log(abs(rawdata[i][2])))/(np.log(10))
# C:\Users\chaowang\homeworkforweek2\plot_IMF.py:15: RuntimeWarning: invalid value encountered in double_scalars
#   for k, g in groupby(sorted(Mag), key=lambda x:x//1):

# %% [markdown]
# 从图上的关系以及选取源的距离等因素，可以推断初始质量函数大概是0.03*Msun^-1.3 ，后面会更陡一些。
